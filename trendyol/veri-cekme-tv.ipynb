# %%
#Gerekli kütüphaneler
import pandas as pd
import numpy as np
import requests
from bs4 import BeautifulSoup

# %%
#Gerekli listeler
url_list = []
prices_list = []
propTitles = []
propValues = []
#Özelliklerin çekilmesi
for i in range(1,2): #2 yerine sayfa sayısı gelmeli
    url = "https://www.trendyol.com/televizyon?pi=" + str(i) #Urlin for döngsü ile güncellenmesi
    r = requests.get(url) #Hazırlanan url'e istek yapılması
    source = BeautifulSoup(r.content,"lxml") #İstek yapılan sayfanın içeriğinin çekilmesi
    
    
    urls = source.find_all("div",attrs={"class":"p-card-chldrn-cntnr"}) #Tüm verilerin bulunması
    for url in urls:
        url_phone = "https://www.trendyol.com/"+url.a.get("href") #Verilerin linklerinin bulunması
        url_list.append(url_phone) #Linklerin kaydedilmesi
        print(url_phone)
        
        r_phone = requests.get(url_phone) #Bulunan linke tekrar istek atılması
        source_phone = BeautifulSoup(r_phone.content,"lxml") #Veri içeriğinin çekilmesi
        
        properties = source_phone.find_all("div",attrs={"class":"prop-item"}) #Bütün özelliklerin bulunması
        for prop in properties:
            prop_title = prop.find("div",attrs={"class":"item-key"}).text
            prop_value = prop.find("div",attrs={"class":"item-value"}).text
            propTitles.append(prop_title)
            propValues.append(prop_value)
        
        
    prices = source.find_all("div",attrs={"class":"prc-box-sllng"}) #Bütün fiyat özelliklerinin bulunması
    for price in prices:
        prices_list.append(price.text) #Bulunan özellikler arasında gezinme ve listeye yazma
        print(price.text)
    
    
        
    
print(str(len(url_list))+" Adet link bulundu.")
print(str(len(prices_list))+" Adet fiyat bulundu.")
print(str(len(propTitles))+" Adet özellik başlığı bulundu.")
print(str(len(propValues))+" Adet özellik verisi bulundu.")
# Out:
# https://www.trendyol.com//samsung/50tu7000-50-125-ekran-uydu-alicili-4k-ultra-hd-smart-led-tv-p-41642762
# https://www.trendyol.com//onvo/ov32151-32-82-ekran-dahili-uydu-smart-wifi-android-led-tv-p-51157971
# https://www.trendyol.com//samsung/55ru7300-55-139-ekran-uydu-alicili-4k-ultra-hd-curved-smart-led-tv-p-6523902
# https://www.trendyol.com//vestel/65u9500-65-165-ekran-uydu-alicili-4k-ultra-hd-smart-led-tv-p-33679979
# https://www.trendyol.com//dijitsu/djtv321-32-81-ekran-uydu-alicili-hd-ready-led-tv-p-39444323
# https://www.trendyol.com//telenova/75s4k8001-20-75-190cm-4k-uhd-dahili-uydu-alicili-android-smart-tv-p-51905717
# https://www.trendyol.com//awox/b203900s-39-99-ekran-uydu-alicili-hd-ready-smart-led-tv-p-44359162
# https://www.trendyol.com//philips/43pus7805-43-109-ekran-uydu-alicili-4k-ultra-hd-smart-led-tv-p-44924741
# https://www.trendyol.com//vestel/32h8500-32-81-ekran-uydu-alicili-hd-ready-led-tv-p-39585119
# https://www.trendyol.com//samsung/55tu7000-55-139-ekran-uydu-alicili-4k-ultra-hd-smart-led-tv-p-42585516
# https://www.trendyol.com//telenova/40s8001-20-40-101-ekran-dahili-uydu-alicili-android-smart-tv-p-50886662
# https://www.trendyol.com//awox/u3200str-32-81-ekran-uydu-alicili-hd-ready-led-tv-p-3898208
# https://www.trendyol.com//samsung/40t5300-40-101-ekran-uydu-alicili-full-hd-smart-led-tv-p-40959827
# https://www.trendyol.com//philips/32pfs5803-32-81-ekran-uydu-alicili-full-hd-smart-led-tv-p-4170138
# https://www.trendyol.com//vestel/49f9500-49-124-ekran-uydu-alicili-full-hd-smart-led-tv-p-40618720
# https://www.trendyol.com//awox/awx6124st-24-61-ekran-uydu-alicili-hd-ready-led-tv-p-2334178
# https://www.trendyol.com//awox/b-205000s-50-127-ekran-uydu-alicili-4k-ultra-hd-smart-android-led-tv-p-36323191
# https://www.trendyol.com//telenova/24d4001-20-24-61cm-dahili-uydu-alicili-led-tv-p-50918388
# https://www.trendyol.com//samsung/40n5000-40-101-ekran-uydu-alicili-full-hd-led-tv-p-3706995
# https://www.trendyol.com//axen/ax43dil13-43-109-ekran-uydu-alicili-full-hd-android-smart-dled-tv-p-35168992
# https://www.trendyol.com//awox/a-202400-24-61-ekran-uydu-alicili-hd-ready-led-tv-p-35889800
# https://www.trendyol.com//philips/43pus7505-43-109-ekran-uydu-alicili-ultra-hd-smart-led-tv-p-48985419
# https://www.trendyol.com//telenova/55s8002-55-139-ekran-full-hd-smart-led-tv-p-43910780
# https://www.trendyol.com//samsung/50tu8500-50-127-ekran-uydu-alicili-4k-ultra-hd-smart-led-tv-p-42314908
# 5.019 TL
# 1.279 TL
# 5.249 TL
# 5.528,02 TL
# 999 TL
# 8.519,99 TL
# 1.499 TL
# 3.979 TL
# 1.359 TL
# 5.829 TL
# 2.699 TL
# 1.099 TL
# 3.036 TL
# 2.050 TL
# 3.081,44 TL
# 789 TL
# 2.899,90 TL
# 964,99 TL
# 2.449 TL
# 1.940 TL
# 789 TL
# 3.599 TL
# 3.399 TL
# 5.488 TL
# 24 Adet link bulundu.
# 24 Adet fiyat bulundu.
# 242 Adet özellik başlığı bulundu.
# 242 Adet özellik verisi bulundu.

# %%
#Url ve fiyatları bir data frame yazma
df_urls = pd.DataFrame()
df_urls["urls"] = url_list
df_urls["prices"] = prices_list

# %%
df_urls.head()
# Out:
#                                                 urls       prices
# 0  https://www.trendyol.com//samsung/50tu7000-50-...     5.019 TL
# 1  https://www.trendyol.com//onvo/ov32151-32-82-e...     1.279 TL
# 2  https://www.trendyol.com//samsung/55ru7300-55-...     5.249 TL
# 3  https://www.trendyol.com//vestel/65u9500-65-16...  5.528,02 TL
# 4  https://www.trendyol.com//dijitsu/djtv321-32-8...       999 TL

# %%
#Bulunan veri sayısı
phones = len(url_list)

# %%
#Bulunan özellik başlıklarının benzersizlerini bulma
columns = np.array(propTitles)
columns = np.unique(columns)

# %%
#Başlıkları kullanarak url ve fiyat ile birlikte yeni bir data frame oluşturma
df = pd.DataFrame(columns=columns)
df["url"] = url_list
df["price"] = prices_list

# %%
#Oluşturulan data frame gösterme
df.head()
# Out:
#   Ekran Boyutu: Garanti Tipi: Görüntü Kalitesi: Görüntüleme Teknolojisi: HDR:  \
# 0           NaN           NaN               NaN                      NaN  NaN
# 1           NaN           NaN               NaN                      NaN  NaN
# 2           NaN           NaN               NaN                      NaN  NaN
# 3           NaN           NaN               NaN                      NaN  NaN
# 4           NaN           NaN               NaN                      NaN  NaN
#
#   Kurulum Gerekli mi?: Renk: Smart TV: Uydu Alıcı: Wi-Fi:  \
# 0                  NaN   NaN       NaN         NaN    NaN
# 1                  NaN   NaN       NaN         NaN    NaN
# 2                  NaN   NaN       NaN         NaN    NaN
# 3                  NaN   NaN       NaN         NaN    NaN
# 4                  NaN   NaN       NaN         NaN    NaN
#
#   Çözünürlük (Piksel):                                                url  \
# 0                  NaN  https://www.trendyol.com//samsung/50tu7000-50-...
# 1                  NaN  https://www.trendyol.com//onvo/ov32151-32-82-e...
# 2                  NaN  https://www.trendyol.com//samsung/55ru7300-55-...
# 3                  NaN  https://www.trendyol.com//vestel/65u9500-65-16...
# 4                  NaN  https://www.trendyol.com//dijitsu/djtv321-32-8...
#
#          price
# 0     5.019 TL
# 1     1.279 TL
# 2     5.249 TL
# 3  5.528,02 TL
# 4       999 TL

# %%
#Data frame'i kullanarak bütün verileri çekme ve sütunlara yazdırma
for i in range(0,phones):
    url = df['url'].loc[i]
    r = requests.get(url)
    source = BeautifulSoup(r.content,"lxml")
    
    properties = source.find_all("div",attrs={"class":"prop-item"})
    for prop in properties:
        prop_title = prop.find("div",attrs={"class":"item-key"}).text
        prop_value = prop.find("div",attrs={"class":"item-value"}).text
        print(prop_title+prop_value)
        df[prop_title].loc[i] = prop_value
# Out:
# Ekran Boyutu:50" / 127 Ekran
# Garanti Tipi:Distribütör Garantili
# Kurulum Gerekli mi?:Evet
# Çözünürlük (Piksel):3840 x 2160
# Smart TV:Var
# Görüntü Kalitesi:4K Ultra HD
# Görüntüleme Teknolojisi:LED
# Renk:Siyah
# HDR:Var
# Wi-Fi:Var
# Uydu Alıcı:Var
# Ekran Boyutu:32" / 81 Ekran
# Garanti Tipi:Distribütör Garantili
# Kurulum Gerekli mi?:Evet
# Çözünürlük (Piksel):1366 x 768
# Smart TV:Var
# Görüntü Kalitesi:HD Ready
# Görüntüleme Teknolojisi:LED
# Renk:Siyah
# HDR:Yok
# Wi-Fi:Var
# Uydu Alıcı:Var
# Ekran Boyutu:55" / 139 Ekran
# Garanti Tipi:Distribütör Garantili
# Görüntü Kalitesi:4K Ultra HD
# Çözünürlük (Piksel):3840 x 2160
# Smart TV:Var
# Uydu Alıcı:Var
# Görüntüleme Teknolojisi:LED
# Renk:Siyah
# HDR:Var
# Wi-Fi:Var
# Ekran Boyutu:65" / 165 Ekran
# Garanti Tipi:Distribütör Garantili
# Görüntü Kalitesi:4K Ultra HD
# Çözünürlük (Piksel):3840 x 2160
# Smart TV:Var
# Uydu Alıcı:Var
# Görüntüleme Teknolojisi:LED
# Renk:Siyah
# HDR:Var
# Wi-Fi:Var
# Ekran Boyutu:32" / 81 Ekran
# Garanti Tipi:Distribütör Garantili
# Görüntü Kalitesi:HD Ready
# Çözünürlük (Piksel):1366 x 768
# Smart TV:Yok
# Uydu Alıcı:Var
# Görüntüleme Teknolojisi:LED
# Renk:Siyah
# HDR:Yok
# Wi-Fi:Yok
# Ekran Boyutu:75" / 190 Ekran
# Garanti Tipi:Distribütör Garantili
# Kurulum Gerekli mi?:Hayır
# Çözünürlük (Piksel):3840 x 2160
# Smart TV:Var
# Görüntü Kalitesi:4K Ultra HD
# Görüntüleme Teknolojisi:LED
# Renk:Siyah
# HDR:Var
# Wi-Fi:Var
# Uydu Alıcı:Var
# Ekran Boyutu:39" / 99 Ekran
# Garanti Tipi:Distribütör Garantili
# Kurulum Gerekli mi?:Hayır
# Çözünürlük (Piksel):1366 x 768
# Smart TV:Var
# Görüntü Kalitesi:HD Ready
# Görüntüleme Teknolojisi:LED
# Renk:Siyah
# HDR:Yok
# Wi-Fi:Var
# Uydu Alıcı:Var
# Ekran Boyutu:43" / 109 Ekran
# Görüntü Kalitesi:4K Ultra HD
# Çözünürlük (Piksel):3840 x 2160
# Smart TV:Var
# Uydu Alıcı:Var
# Görüntüleme Teknolojisi:LED
# Renk:Siyah
# HDR:Var
# Wi-Fi:Var
# Kurulum Gerekli mi?:Evet
# Ekran Boyutu:32" / 81 Ekran
# Garanti Tipi:Distribütör Garantili
# Görüntü Kalitesi:HD Ready
# Çözünürlük (Piksel):1366 x 768
# Smart TV:Yok
# Uydu Alıcı:Var
# Görüntüleme Teknolojisi:LED
# Renk:Siyah
# HDR:Yok
# Wi-Fi:Yok
# Ekran Boyutu:55" / 139 Ekran
# Garanti Tipi:Distribütör Garantili
# Kurulum Gerekli mi?:Evet
# Çözünürlük (Piksel):3840 x 2160
# Smart TV:Var
# Görüntü Kalitesi:4K Ultra HD
# Görüntüleme Teknolojisi:LED
# Renk:Siyah
# HDR:Var
# Wi-Fi:Var
# Uydu Alıcı:Var
# Ekran Boyutu:40" / 101 Ekran
# Garanti Tipi:Distribütör Garantili
# Kurulum Gerekli mi?:Hayır
# Çözünürlük (Piksel):1920 x 1080
# Smart TV:Var
# Görüntü Kalitesi:Full HD
# Görüntüleme Teknolojisi:LED
# Renk:Siyah
# HDR:Yok
# Wi-Fi:Var
# Uydu Alıcı:Var
# Ekran Boyutu:32" / 81 Ekran
# Garanti Tipi:Distribütör Garantili
# Görüntü Kalitesi:HD Ready
# Çözünürlük (Piksel):1366 x 768
# Smart TV:Yok
# Uydu Alıcı:Var
# Görüntüleme Teknolojisi:LED
# Renk:Siyah
# HDR:Yok
# Wi-Fi:Yok
# Ekran Boyutu:40" / 101 Ekran
# Garanti Tipi:Distribütör Garantili
# Görüntü Kalitesi:Full HD
# Çözünürlük (Piksel):1920 x 1080
# Smart TV:Var
# Uydu Alıcı:Var
# Görüntüleme Teknolojisi:LED
# Renk:Siyah
# HDR:Yok
# Wi-Fi:Var
# Ekran Boyutu:32" / 81 Ekran
# Garanti Tipi:Distribütör Garantili
# Görüntü Kalitesi:Full HD
# Çözünürlük (Piksel):1920 x 1080
# Smart TV:Var
# Uydu Alıcı:Var
# Görüntüleme Teknolojisi:LED
# Renk:Siyah
# HDR:Yok
# Wi-Fi:Var
# Ekran Boyutu:49" / 124 Ekran
# Garanti Tipi:Distribütör Garantili
# Görüntü Kalitesi:Full HD
# Çözünürlük (Piksel):1920 x 1080
# Smart TV:Var
# Uydu Alıcı:Var
# Görüntüleme Teknolojisi:LED
# Renk:Siyah
# HDR:Yok
# Wi-Fi:Var
# Ekran Boyutu:24" / 61 Ekran
# Garanti Tipi:Distribütör Garantili
# Kurulum Gerekli mi?:Hayır
# Çözünürlük (Piksel):1366 x 768
# Smart TV:Yok
# Görüntü Kalitesi:HD Ready
# Görüntüleme Teknolojisi:LED
# Renk:Siyah
# HDR:Yok
# Wi-Fi:Yok
# Uydu Alıcı:Var
# Ekran Boyutu:50" / 127 Ekran
# Smart TV:Var
# Renk:Beyaz
# Wi-Fi:Var
# Ekran Boyutu:24" / 61 Ekran
# Garanti Tipi:Distribütör Garantili
# Kurulum Gerekli mi?:Hayır
# Çözünürlük (Piksel):1920 x 1080
# Smart TV:Yok
# Görüntü Kalitesi:Full HD
# Görüntüleme Teknolojisi:LED
# Renk:Siyah
# HDR:Yok
# Wi-Fi:Yok
# Uydu Alıcı:Var
# Ekran Boyutu:40" / 101 Ekran
# Garanti Tipi:Distribütör Garantili
# Görüntü Kalitesi:HD Ready
# Çözünürlük (Piksel):1366 x 768
# Smart TV:Yok
# Uydu Alıcı:Var
# Görüntüleme Teknolojisi:LED
# Renk:Siyah
# HDR:Yok
# Wi-Fi:Yok
# Ekran Boyutu:43" / 109 Ekran
# Görüntü Kalitesi:Full HD
# Çözünürlük (Piksel):1920 x 1080
# Smart TV:Var
# Uydu Alıcı:Var
# Görüntüleme Teknolojisi:LED
# Renk:Siyah
# Wi-Fi:Var
# Ekran Boyutu:24" / 61 Ekran
# Garanti Tipi:Distribütör Garantili
# Görüntü Kalitesi:HD Ready
# Çözünürlük (Piksel):1366 x 768
# Smart TV:Yok
# Uydu Alıcı:Var
# Görüntüleme Teknolojisi:LED
# Renk:Siyah
# HDR:Yok
# Wi-Fi:Yok
# Ekran Boyutu:43" / 109 Ekran
# Garanti Tipi:Distribütör Garantili
# Kurulum Gerekli mi?:Evet
# Çözünürlük (Piksel):3840 x 2160
# Smart TV:Var
# Görüntü Kalitesi:4K Ultra HD
# Görüntüleme Teknolojisi:LED
# Renk:Siyah
# HDR:Var
# Wi-Fi:Var
# Uydu Alıcı:Var
# Ekran Boyutu:55" / 139 Ekran
# Garanti Tipi:İthalatçı Garantili
# Görüntü Kalitesi:Full HD
# Çözünürlük (Piksel):1920 x 1080
# Smart TV:Var
# Uydu Alıcı:Var
# Görüntüleme Teknolojisi:LED
# Renk:Gri
# HDR:Yok
# Wi-Fi:Var
# Ekran Boyutu:50" / 127 Ekran
# Garanti Tipi:Distribütör Garantili
# Kurulum Gerekli mi?:Evet
# Çözünürlük (Piksel):3840 x 2160
# Smart TV:Var
# Görüntü Kalitesi:4K Ultra HD
# Görüntüleme Teknolojisi:LED
# Renk:Siyah
# HDR:Var
# Wi-Fi:Var
# Uydu Alıcı:Var

# %%
df.head()
# Out:
#      Ekran Boyutu:          Garanti Tipi: Görüntü Kalitesi:  \
# 0  50" / 127 Ekran  Distribütör Garantili       4K Ultra HD
# 1   32" / 81 Ekran  Distribütör Garantili          HD Ready
# 2  55" / 139 Ekran  Distribütör Garantili       4K Ultra HD
# 3  65" / 165 Ekran  Distribütör Garantili       4K Ultra HD
# 4   32" / 81 Ekran  Distribütör Garantili          HD Ready
#
#   Görüntüleme Teknolojisi: HDR: Kurulum Gerekli mi?:  Renk: Smart TV:  \
# 0                      LED  Var                 Evet  Siyah       Var
# 1                      LED  Yok                 Evet  Siyah       Var
# 2                      LED  Var                  NaN  Siyah       Var
# 3                      LED  Var                  NaN  Siyah       Var
# 4                      LED  Yok                  NaN  Siyah       Yok
#
#   Uydu Alıcı: Wi-Fi: Çözünürlük (Piksel):  \
# 0         Var    Var          3840 x 2160
# 1         Var    Var           1366 x 768
# 2         Var    Var          3840 x 2160
# 3         Var    Var          3840 x 2160
# 4         Var    Yok           1366 x 768
#
#                                                  url        price
# 0  https://www.trendyol.com//samsung/50tu7000-50-...     5.019 TL
# 1  https://www.trendyol.com//onvo/ov32151-32-82-e...     1.279 TL
# 2  https://www.trendyol.com//samsung/55ru7300-55-...     5.249 TL
# 3  https://www.trendyol.com//vestel/65u9500-65-16...  5.528,02 TL
# 4  https://www.trendyol.com//dijitsu/djtv321-32-8...       999 TL

# %%
#Data frame'i csv formatına çevirip kaydetme
df.to_csv("./data/tv_data.csv",index=False)
